# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = "svg"
x = np.linspace(-5,5,100)
plt.plot(x,np.sin(x)/(1+x**2), label="Casey’s Plot")
plt.xlabel("x")
plt.ylabel("$\Psi(x)$")
# Out:
# Text(0, 0.5, '$\\Psi(x)$')

# %%
label="Casey's Plot"

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = "svg"
x = np.linspace(-5,5,100)
plt.plot(x,np.sin(x)/(1+x**2), label="Casey’s Plot")
plt.xlabel("x")
plt.ylabel("$\Psi(x)$")
im1=im1.save("Casey's Plot")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-c86e5ad67851> in <module>
#       7 plt.xlabel("x")
#       8 plt.ylabel("$\Psi(x)$")
# ----> 9 im1=im1.save("Casey's Plot")
#
# NameError: name 'im1' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = "svg"
x = np.linspace(-5,5,100)
plt.plot(x,np.sin(x)/(1+x**2), label="Casey’s Plot")
plt.xlabel("x")
plt.ylabel("$\Psi(x)$")
# Out:
# Text(0, 0.5, '$\\Psi(x)$')

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = "svg"
x = np.linspace(-5,5,100)
plt.plot(x,np.sin(x)/(1+x**2), label="Casey’s Plot")
plt.title("Casey's Plot")
plt.xlabel("x")
plt.ylabel("$\Psi(x)$")
# Out:
# Text(0, 0.5, '$\\Psi(x)$')

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = "svg"
x = np.linspace(-5,5,100)
plt.plot(x,np.sin(x)/(1+x**2), label="Casey’s Plot")
plt.title("Casey's Plot")
plt.xlabel("x")
plt.ylabel("$\Psi(x)$")
plt.savefig("Casey's Plot", format="svg")

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = "svg"
x = np.linspace(-5,5,100)
plt.plot(x,np.sin(x)/(1+x**2), label="Casey’s Plot")
plt.title("Casey's Plot")
plt.xlabel("x")
plt.ylabel("$\Psi(x)$")
plt.savefig("Casey's Plot")

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
x = np.linspace(-5,5,100)
plt.plot(x,np.sin(x)/(1+x**2), label="Casey’s Plot")
plt.title("Casey's Plot")
plt.xlabel("x")
plt.ylabel("$\Psi(x)$")
plt.savefig("output.svg")
