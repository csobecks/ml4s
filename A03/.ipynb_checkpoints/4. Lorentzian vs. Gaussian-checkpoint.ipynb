# %% [markdown]
# # Lorentzian vs. Gaussian
# Use tensorflow.keras to build a simple binary
# classifier that can distinguish between
# one-dimensional Lorentzians $L(x)$ and Gaussians
# $N(x)$ where:
# \begin{equation}
#     L(x)=\frac{A}{(x-\mu)^2\sigma^2+1}\\
#     N(x)=Ae^{-(x-\mu)^2/(2\sigma^2)}
# \end{equation}
# Here A is the amplitude, $\mu$ the location of the peaks, and $\sigma$ the width. You are free to choose any
# values for these you like, but I suggest you start simple.

# %%
# %load ./include/header.py
import numpy as np
import matplotlib.pyplot as plt
import sys
sys.path.append('./include')
import ml4s
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
plt.style.use('./include/notebook.mplstyle')
np.set_printoptions(linewidth=120)
ml4s._set_css_style('./include/bootstrap.css')
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import datetime
from tqdm import trange,tqdm
import math

# %% [markdown]
# ## Part a
# Write a function that can generate your dataset. This should include a large number of random
# functions $L$ and $N$ on the line -5$\leq x \leq$ 5 where A, $\sigma$, $\mu$ are uniformly distributed random
# numbers as seen in the figure. The input values will be either $N(x)$ or $L(x)$ while the targets
# are 1 for Gaussian and 0 for Lorentzian.

# %%
def dataset(size):
    target=np.zeros([size,4])
    for i in range(size):
        A=np.random.uniform(low=0, high=1.0)
        σ=np.random.uniform(low=0, high=1.0)
        μ=np.random.uniform(low=-3.0, high=3.0)
        choice=np.random.uniform(low=-1.0, high=1.0)
        target[i][0]=A
        target[i][1]=σ
        target[i][2]=μ
        if choice>=0:
            target[i][3]=1
        else:
            target[i][3]=0
    return target

# %%
size=1000
target=np.zeros([size,4])
target=dataset(size)
#print(target)

# %%
x=np.linspace(-5.0, 5.0, 1000)
y=np.zeros((1000,size))

for i in range(size):
    if target[i][3]==0:
        for j in range(len(x)):
            y[j][i]=target[i][0]/((((x[j]-target[i][2])**2)/(target[i][1]**2))+1)
    else:
        for j in range(len(x)):
            e=(((x[j]-target[i][2])**2)/(2*(target[i][1]**2)))
            y[j][i]=target[i][0]*np.exp(-1*e)
# plt.plot(x,y)
    
# plt.xlim([-5,5])
# plt.ylim([0,1])

# %% [markdown]
# ## Part b
# Using the binary cross entropy as your cost function, train your network to distinguish between
# them. What level of accuracy can you achieve with 10 functions? 100? 1000?

# %%
label=target[:,-1]#.transpose()#astype(dtype=int).transpose
thing=y[:,:].astype(dtype=float)
L=len(thing)
testing=thing.transpose()

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(testing, label, test_size=0.1)

model = keras.Sequential(
[
    layers.Dense(20,input_shape=(L,),activation='relu'),
    layers.Dense(40,input_shape=(L,),activation='relu'),
    layers.Dense(80,input_shape=(L,),activation='relu'),
    layers.Dense(40,input_shape=(L,),activation='relu'),
    layers.Dense(10,input_shape=(L,),activation='relu'),
    layers.Dense(1, activation='sigmoid', bias_initializer='zeros')
])
model.summary()
# Out:
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_52 (Dense)             (None, 20)                20020
# _________________________________________________________________
# dense_53 (Dense)             (None, 40)                840
# _________________________________________________________________
# dense_54 (Dense)             (None, 80)                3280
# _________________________________________________________________
# dense_55 (Dense)             (None, 40)                3240
# _________________________________________________________________
# dense_56 (Dense)             (None, 10)                410
# _________________________________________________________________
# dense_57 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 27,801
# Trainable params: 27,801
# Non-trainable params: 0
# _________________________________________________________________

# %%
np.shape(x_train)
# Out:
# (900, 1000)

# %%
model.compile(loss=keras.losses.binary_crossentropy, optimizer='adam', metrics=['accuracy'])

# %%
model.compile(loss=keras.losses.binary_crossentropy, optimizer='adam', metrics=['accuracy']) 
batch_size = 100
epochs = 30
training_history = {}
training_history['test'] = model.fit(x_train,y_train, epochs=epochs,validation_data=(x_test,y_test), verbose=1)
# Out:
# Epoch 1/30
# 29/29 [==============================] - 4s 115ms/step - loss: 0.6914 - accuracy: 0.5541 - val_loss: 0.6727 - val_accuracy: 0.5300
# Epoch 2/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.6528 - accuracy: 0.6231 - val_loss: 0.6107 - val_accuracy: 0.7100
# Epoch 3/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.5832 - accuracy: 0.7052 - val_loss: 0.4868 - val_accuracy: 0.7700
# Epoch 4/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.4704 - accuracy: 0.7643 - val_loss: 0.4389 - val_accuracy: 0.7700
# Epoch 5/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.3587 - accuracy: 0.8282 - val_loss: 0.3901 - val_accuracy: 0.8100
# Epoch 6/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.3435 - accuracy: 0.8247 - val_loss: 0.3504 - val_accuracy: 0.8200
# Epoch 7/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2849 - accuracy: 0.8705 - val_loss: 0.3116 - val_accuracy: 0.8600
# Epoch 8/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2681 - accuracy: 0.8836 - val_loss: 0.2930 - val_accuracy: 0.8300
# Epoch 9/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1946 - accuracy: 0.9320 - val_loss: 0.2346 - val_accuracy: 0.8800
# Epoch 10/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1877 - accuracy: 0.9206 - val_loss: 0.2327 - val_accuracy: 0.8700
# Epoch 11/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1565 - accuracy: 0.9270 - val_loss: 0.2042 - val_accuracy: 0.8800
# Epoch 12/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1381 - accuracy: 0.9437 - val_loss: 0.1792 - val_accuracy: 0.9000
# Epoch 13/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1243 - accuracy: 0.9605 - val_loss: 0.2170 - val_accuracy: 0.8600
# Epoch 14/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1150 - accuracy: 0.9526 - val_loss: 0.1902 - val_accuracy: 0.8900
# Epoch 15/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0692 - accuracy: 0.9857 - val_loss: 0.2079 - val_accuracy: 0.8600
# Epoch 16/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1075 - accuracy: 0.9651 - val_loss: 0.1754 - val_accuracy: 0.9100
# Epoch 17/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0800 - accuracy: 0.9757 - val_loss: 0.1496 - val_accuracy: 0.9000
# Epoch 18/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0875 - accuracy: 0.9700 - val_loss: 0.1867 - val_accuracy: 0.9100
# Epoch 19/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0642 - accuracy: 0.9808 - val_loss: 0.1648 - val_accuracy: 0.9400
# Epoch 20/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0632 - accuracy: 0.9829 - val_loss: 0.2002 - val_accuracy: 0.9100
# Epoch 21/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0482 - accuracy: 0.9874 - val_loss: 0.2143 - val_accuracy: 0.9300
# Epoch 22/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0431 - accuracy: 0.9888 - val_loss: 0.2243 - val_accuracy: 0.9100
# Epoch 23/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0387 - accuracy: 0.9881 - val_loss: 0.2803 - val_accuracy: 0.8900
# Epoch 24/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0558 - accuracy: 0.9800 - val_loss: 0.2966 - val_accuracy: 0.8900
# Epoch 25/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0704 - accuracy: 0.9750 - val_loss: 0.2165 - val_accuracy: 0.9400
# Epoch 26/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0725 - accuracy: 0.9804 - val_loss: 0.1597 - val_accuracy: 0.9400
# Epoch 27/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0588 - accuracy: 0.9744 - val_loss: 0.2076 - val_accuracy: 0.9300
# Epoch 28/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0298 - accuracy: 0.9930 - val_loss: 0.2517 - val_accuracy: 0.8900
# Epoch 29/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0377 - accuracy: 0.9881 - val_loss: 0.2001 - val_accuracy: 0.9500
# Epoch 30/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0263 - accuracy: 0.9895 - val_loss: 0.2095 - val_accuracy: 0.9300

# %%
# evaluate model
score = model.evaluate(x_test, y_test, verbose=2)

predictions = np.zeros(testing.shape[0],dtype=int)
predictions[np.where(model(testing)>=0.5)[0]] = 1

mistakes = np.where(label != predictions)[0]
num_mistakes = len(mistakes)

print(f'Num. Mistakes  = {num_mistakes}')
# Out:
# 4/4 - 0s - loss: 0.2095 - accuracy: 0.9300
# Num. Mistakes  = 14

# %%
# look into training history
fig,ax = plt.subplots(2,1, sharex=True, sharey=True, figsize=(5,5))

# summarize history for accuracy
ax[0].plot(training_history['test'].history['accuracy'])
ax[0].plot(training_history['test'].history['val_accuracy'], ls='--', color=colors[-3])
ax[0].set_ylabel('model accuracy')
ax[0].legend(['train', 'test'], loc='best')
ax[0].set_ylim(0,1)

# summarize history for loss
ax[1].plot(training_history['test'].history['loss'])
ax[1].plot(training_history['test'].history['val_loss'], ls='--', color=colors[-3])
ax[1].set_ylabel('model loss')
ax[1].set_xlabel('epoch')
ax[1].legend(['train', 'test'], loc='best');

# %% [markdown]
# ## Part c
# How does the performance of your deep neural network compare to logistic
# regression? You can either write your own code to do this, or use some libraries (like
# scikit.learn).

# %%
testing_1=thing.transpose()
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(testing_1, label, test_size=0.1)

model = keras.Sequential(
[
    layers.Dense(10,input_shape=(L,),activation='relu'),
    layers.Dense(1, activation='sigmoid', bias_initializer='zeros')
])
model.compile(loss=keras.losses.binary_crossentropy, optimizer='adam', metrics=['accuracy'])
batch_size = 100
epochs = 30
training_history = {}
training_history['test_1'] = model.fit(x_train,y_train, epochs=epochs,validation_data=(x_test,y_test), verbose=1)
# Out:
# Epoch 1/30
# 29/29 [==============================] - 1s 8ms/step - loss: 0.6921 - accuracy: 0.5292 - val_loss: 0.6662 - val_accuracy: 0.6600
# Epoch 2/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.6630 - accuracy: 0.6722 - val_loss: 0.6505 - val_accuracy: 0.5400
# Epoch 3/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.6457 - accuracy: 0.6500 - val_loss: 0.6373 - val_accuracy: 0.6700
# Epoch 4/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.6160 - accuracy: 0.7354 - val_loss: 0.6041 - val_accuracy: 0.7100
# Epoch 5/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.5954 - accuracy: 0.7311 - val_loss: 0.5860 - val_accuracy: 0.7000
# Epoch 6/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.5760 - accuracy: 0.7795 - val_loss: 0.5731 - val_accuracy: 0.7300
# Epoch 7/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.5586 - accuracy: 0.7812 - val_loss: 0.5626 - val_accuracy: 0.7200
# Epoch 8/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.5122 - accuracy: 0.8038 - val_loss: 0.5627 - val_accuracy: 0.7700
# Epoch 9/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.5176 - accuracy: 0.8025 - val_loss: 0.5422 - val_accuracy: 0.7500
# Epoch 10/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.5099 - accuracy: 0.7811 - val_loss: 0.5300 - val_accuracy: 0.7800
# Epoch 11/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.4787 - accuracy: 0.8103 - val_loss: 0.5297 - val_accuracy: 0.7800
# Epoch 12/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.4621 - accuracy: 0.8333 - val_loss: 0.5227 - val_accuracy: 0.7800
# Epoch 13/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.4597 - accuracy: 0.8267 - val_loss: 0.5124 - val_accuracy: 0.8100
# Epoch 14/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.4378 - accuracy: 0.8282 - val_loss: 0.5011 - val_accuracy: 0.7400
# Epoch 15/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.4319 - accuracy: 0.8354 - val_loss: 0.4935 - val_accuracy: 0.8100
# Epoch 16/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.4294 - accuracy: 0.8355 - val_loss: 0.4814 - val_accuracy: 0.8100
# Epoch 17/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.4355 - accuracy: 0.8207 - val_loss: 0.4849 - val_accuracy: 0.7800
# Epoch 18/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.4106 - accuracy: 0.8420 - val_loss: 0.4638 - val_accuracy: 0.8000
# Epoch 19/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.4084 - accuracy: 0.8377 - val_loss: 0.4667 - val_accuracy: 0.8000
# Epoch 20/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.3881 - accuracy: 0.8529 - val_loss: 0.4547 - val_accuracy: 0.8300
# Epoch 21/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.3749 - accuracy: 0.8553 - val_loss: 0.4686 - val_accuracy: 0.7900
# Epoch 22/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.3580 - accuracy: 0.8641 - val_loss: 0.4385 - val_accuracy: 0.8200
# Epoch 23/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.3679 - accuracy: 0.8643 - val_loss: 0.4337 - val_accuracy: 0.8200
# Epoch 24/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.3653 - accuracy: 0.8693 - val_loss: 0.4260 - val_accuracy: 0.8200
# Epoch 25/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.3507 - accuracy: 0.8799 - val_loss: 0.4144 - val_accuracy: 0.8300
# Epoch 26/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.3668 - accuracy: 0.8502 - val_loss: 0.4218 - val_accuracy: 0.8100
# Epoch 27/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.3421 - accuracy: 0.8819 - val_loss: 0.4316 - val_accuracy: 0.8300
# Epoch 28/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.3472 - accuracy: 0.8637 - val_loss: 0.4176 - val_accuracy: 0.8500
# Epoch 29/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.3374 - accuracy: 0.8676 - val_loss: 0.3974 - val_accuracy: 0.8200
# Epoch 30/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.3473 - accuracy: 0.8824 - val_loss: 0.3870 - val_accuracy: 0.8000

# %%
# evaluate model
score = model.evaluate(x_test, y_test, verbose=2)

predictions = np.zeros(testing_1.shape[0],dtype=int)
predictions[np.where(model(testing_1)>=0.5)[0]] = 1

mistakes = np.where(label != predictions)[0]
num_mistakes = len(mistakes)

print(f'Num. Mistakes  = {num_mistakes}')
# Out:
# 4/4 - 0s - loss: 0.3870 - accuracy: 0.8000
# Num. Mistakes  = 124

# %%
# look into training history
fig,ax = plt.subplots(2,1, sharex=True, sharey=True, figsize=(5,5))

# summarize history for accuracy
ax[0].plot(training_history['test_1'].history['accuracy'])
ax[0].plot(training_history['test_1'].history['val_accuracy'], ls='--', color=colors[-3])
ax[0].set_ylabel('model accuracy')
ax[0].legend(['train', 'test_1'], loc='best')
ax[0].set_ylim(0,1)

# summarize history for loss
ax[1].plot(training_history['test_1'].history['loss'])
ax[1].plot(training_history['test_1'].history['val_loss'], ls='--', color=colors[-3])
ax[1].set_ylabel('model loss')
ax[1].set_xlabel('epoch')
ax[1].legend(['train', 'test_1'], loc='best');

# %% [markdown]
# ### Comment:
# The deep neural network works much better than logistic regression. This could have been guessed from the start since the deep neural network has a greater ability to learn when compared to logistic regression. That being said, logistic regression did perform well as the number of epochs increased. This method could be employed if there is a lack of resources to create and run a complex deep neural network
